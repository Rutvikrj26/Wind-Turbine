# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# Getting relevant data in form of structured Data Frames
#data = pd.DataFrame(pd.read_csv('data_0.0017_1.txt'))
data = pd.DataFrame(pd.read_csv('data_unmodified_0.1x0.1_0.001.txt'))
data_array = pd.DataFrame.to_numpy(data).tolist()
data_wing_1 = pd.DataFrame.to_numpy(data[data.j == 0]).tolist()
data_wing_2 = pd.DataFrame.to_numpy(data[data.j == 1]).tolist()
data_wing_3 = pd.DataFrame.to_numpy(data[data.j == 2]).tolist()

exp_data = pd.read_csv('thesis data')

# %%
data_to_analyse = data_wing_1

theta_force = {}
theta_vel = {}
theta_alpha = {}
theta_cts = {}

theta_vel_cur = {}
theta_alpha_cur = {}
theta_force_cur = {}
theta_cts_cur = {}

for i in range(len(data_to_analyse)):
    value = (data_to_analyse[i][1])
    value_limit = (data_to_analyse[i][1])%360

    theta_force[value] = data_to_analyse[i][5]#[7]
    theta_force_cur[value_limit] = data_to_analyse[i][5]

    theta_vel[value] = data_to_analyse[i][3]
    theta_vel_cur[value_limit] = data_to_analyse[i][3]#[5]

    theta_alpha[value] = data_to_analyse[i][2]
    theta_alpha_cur[value_limit] = data_to_analyse[i][2]#[5]

    theta_cts[value] = data_to_analyse[i][4]
    theta_cts_cur[value_limit] = data_to_analyse[i][4]

# %%
lists = sorted(theta_force.items()) # sorted by key, return a list of tuples

x, y = zip(*lists) # unpack a list of pairs into two tuples

plt.plot(np.array(x), np.array(y), '--')#/(25.725*25))
plt.xlabel('Force')
plt.ylabel('theta')
# Out:
# Text(0, 0.5, 'theta')
